# %% [markdown]
# # Medical insurance

# %%
import pandas as pd
import plotly as plt
from scipy import stats
from scipy.stats import boxcox
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_read = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/insurance.csv')

# %%
df_read
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df_read.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df_read.shape
# Out:
# (1338, 7)

# %% [markdown]
# ## checking the NAN-values

# %%
# checking the NAN-values

df_read.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [markdown]
# ## identifying the duplicates

# %%
df_read.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## removing the dupliactes

# %%
df_read.drop_duplicates(inplace=True)

# %%
df_read.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %% [markdown]
# ## Identifying data types of columns

# %%
df_read.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
df_read.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1337 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1337 non-null   int64
#  1   sex       1337 non-null   object
#  2   bmi       1337 non-null   float64
#  3   children  1337 non-null   int64
#  4   smoker    1337 non-null   object
#  5   region    1337 non-null   object
#  6   charges   1337 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 83.6+ KB

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# ### Non-Vizualization

# %%
# calculating max, min, mean, median, std to numerical column = 'age'


print("minimum:",df_read["age"].min())
print("maximum:",df_read["age"].max())
print("mean:",df_read["age"].mean())
print("median:",df_read["age"].median())
print("std:",df_read["age"].std())
# Out:
# minimum: 18
# maximum: 64
# mean: 39.20702541106129
# median: 39.0
# std: 14.049960379216154

# %% [markdown]
# ### Vizualization for age
#
# 1.   It is clear that "AGE" column as no outlier by using "BOX-Plot" Graph.
# 2.   The Second Graph show's the distribution of "AGE" column using "KDE" plot.
# 3.   The Third Graph show's the distribution of "AGE" column using "HIST" plot.

# %%
df_read["age"].plot(kind='box')
# Out:
# <Axes: >

# %%
df_read["age"].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df_read["age"].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ### Non-Vizualization (Statistical Analysis) for CHildren

# %%
# calculating max, min, mean, median, std to numerical column = 'children'


print("maximum:",df_read["children"].min())
print("minimum:",df_read["children"].max())
print("mean:",df_read["children"].mean())
print("median:",df_read["children"].median())
print("std:",df_read["children"].std())
# Out:
# maximum: 0
# minimum: 5
# mean: 1.0949177877429
# median: 1.0
# std: 1.205492739781914

# %%
df_read[df_read["children"]>5]
# Out:
# Empty DataFrame
# Columns: [age, sex, bmi, children, smoker, region, charges]
# Index: []

# %% [markdown]
# ### Vizualization for children
# 1.   It is clear that "Children" column as no outlier by using "BOX-Plot" Graph.
# 2.   The Second Graph show's the distribution of "AGE" column using "KDE" plot.
# 3.   The Third Graph show's the distribution of "AGE" column using "HIST" plot.

# %%
df_read["children"].plot(kind='box')
# Out:
# <Axes: >

# %%
df_read["children"].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df_read["children"].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
# calculating max, min, mean, median, std to numerical column = 'bmi'


print("maximum:",df_read['bmi'].min())
print("minimum:",df_read["bmi"].max())
print("mean:",df_read["bmi"].mean())
print("median:",df_read["bmi"].median())
print("std:",df_read["bmi"].std())
# Out:
# maximum: 15.96
# minimum: 53.13
# mean: 30.66339686098655
# median: 30.4
# std: 6.098186911679014

# %%
print(df_read.shape)
# Out:
# (1338, 7)

# %%
cleand_df=df_read[(df_read["bmi"] <= 47) ]

[print(cleand_df.shape)]

cleand_df["bmi"].plot(kind='box')
# Out:
# (1329, 7)
# <Axes: >

# %%
# calculating max, min, mean, median, std to clean numerical column = 'children'


print("maximum:",cleand_df['bmi'].min())
print("minimum:",cleand_df["bmi"].max())
print("mean:",cleand_df["bmi"].mean())
print("median:",cleand_df["bmi"].median())
print("std:",cleand_df["bmi"].std())
# Out:
# maximum: 15.96
# minimum: 46.75
# mean: 30.53734762979684
# median: 30.3
# std: 5.919946435122972

# %%
cleand_df["bmi"].plot(kind="kde")
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# ## Non-Vizualization (Statistical Analysis) for "charges"

# %%
# calculating max, min, mean, median, std to numerical column = 'charges'


print("maximum:",cleand_df["charges"].min())
print("minimum:",cleand_df["charges"].max())
print("mean:",cleand_df["charges"].mean())
print("median:",cleand_df["charges"].median())
print("std:",cleand_df["charges"].std())
# Out:
# maximum: 1121.8739
# minimum: 62592.87309
# mean: 13212.33337437848
# median: 9361.3268
# std: 11997.236429208286

# %% [markdown]
# ### Vizualization for charges

# %%
cleand_df["charges"].plot(kind='box')
# Out:
# <Axes: >

# %%
cleand_df["charges"].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
cleand_df.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
# calculating max categoric column = 'sex'

print("maximum:",cleand_df["sex"].value_counts())
# Out:
# maximum: male      670
# female    659
# Name: sex, dtype: int64

# %% [markdown]
# Vizualization for Column = "Sex"

# %%
cleand_df["sex"].value_counts().plot(kind="bar")
# Rotating the x-axis tick labels to be horizontal
plt.xticks(rotation=0)
# Out:
# (array([0, 1]), [Text(0, 0, 'male'), Text(1, 0, 'female')])

# %%
# calculating max categoric column = 'smoker'

print("maximum:",cleand_df["smoker"].value_counts())
# Out:
# maximum: no     1058
# yes     271
# Name: smoker, dtype: int64

# %% [markdown]
# ## Vizualization for column = "Smoker"

# %%
cleand_df["smoker"].value_counts().plot(kind="bar",xlabel="smoker")
# Rotating the x-axis tick labels to be horizontal
plt.xticks(rotation=0)
# Out:
# (array([0, 1]), [Text(0, 0, 'no'), Text(1, 0, 'yes')])

# %%
# calculating max categoric column = 'region'

print("maximum:",cleand_df["region"].value_counts())
# Out:
# maximum: southeast    357
# northwest    325
# southwest    324
# northeast    323
# Name: region, dtype: int64

# %% [markdown]
# ## Vizualisation for column = "Region"

# %%
cleand_df["region"].value_counts().plot(kind="bar")
# Rotating the x-axis tick labels to be horizontal
plt.xticks(rotation=0)
# Out:
# (array([0, 1, 2, 3]),
#  [Text(0, 0, 'southeast'),
#   Text(1, 0, 'northwest'),
#   Text(2, 0, 'southwest'),
#   Text(3, 0, 'northeast')])

# %% [markdown]
# # Bivariate Analysis
# ### After Cleaning the data

# %%
cleand_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1329 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1329 non-null   int64
#  1   sex       1329 non-null   object
#  2   bmi       1329 non-null   float64
#  3   children  1329 non-null   int64
#  4   smoker    1329 non-null   object
#  5   region    1329 non-null   object
#  6   charges   1329 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 83.1+ KB

# %% [markdown]
# ## Relationship between Age and Charges - [Numerical Vs Numerical]

# %%
plt.scatter(x = cleand_df['age'],y = cleand_df['charges'])

# %% [markdown]
# ##### As Age increases the charges will be Impacted.

# %% [markdown]
# ## Relationship between bmi and Charges - [Numerical Vs Numerical]

# %%
plt.scatter(x = cleand_df['bmi'],y = cleand_df['charges'])

# %% [markdown]
# #### There is no relationship between bmi and charges

# %% [markdown]
# # Relationship between children and Charges - [Numerical Vs Numerical]

# %%
plt.scatter(x = cleand_df['children'],y = cleand_df['charges'])

# %% [markdown]
# ##### -- There is no relationship Between Children and charges

# %% [markdown]
# # Relationship between sex and Charges - [Categorical Vs Numerical]

# %%
cleand_df.boxplot(by='sex', column='charges')
# Out:
# <Axes: title={'center': 'charges'}, xlabel='sex'>

# %% [markdown]
# ##### There is no relationship between sex and charges

# %% [markdown]
# # Relationship between smoker and Charges - [Categorical Vs Numerical]

# %%
cleand_df.boxplot(by='smoker', column='charges')
# Out:
# <Axes: title={'center': 'charges'}, xlabel='smoker'>

# %% [markdown]
# ###There is Positive relationship between "smoker" equals to 'Yes' and charges.
# 1.Those who smokes will get more medical charges billed by health insurance

# %%
# collecting data from dataframe "bc" in columns "sex" and "smoker"
smoker_counts = cleand_df[cleand_df["smoker"] == "yes"]["sex"].value_counts()

# Creating bar chart
smoker_counts.plot(kind='bar', xlabel= 'Gender', ylabel = 'Count', title = 'Number of Smokers by Gender')
plt.xticks(rotation=0)
# Out:
# (array([0, 1]), [Text(0, 0, 'male'), Text(1, 0, 'female')])

# %%
# collecting data from dataframe "bc" in columns "sex" and "smoker"
non_smoker_counts = cleand_df[cleand_df["smoker"] == "No"]["sex"].value_counts()

# Creating bar chart
smoker_counts.plot(kind='bar', xlabel= 'Gender', ylabel = 'Count', title = 'Number of Non_Smokers by Gender')
plt.xticks(rotation=0)
# Out:
# (array([0, 1]), [Text(0, 0, 'male'), Text(1, 0, 'female')])

# %% [markdown]
# # Relationship between region and Charges - [Categorical Vs Numerical]

# %%
cleand_df.boxplot(by='region', column='charges')
# Out:
# <Axes: title={'center': 'charges'}, xlabel='region'>

# %% [markdown]
# ##### There is no relationship between region and charges.
# 1. Compare to all other regions,southeast region has more charges.

# %%
import seaborn as sns

# Creating a correlation matrix based on the 'charges' column and other numerical columns
corr_matrix = cleand_df.corr()

# Plotting the heatmap
plt.figure(figsize=(10, 8))  # Adjust the figure size if needed
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.4)
plt.title('Correlation Heatmap')
plt.show()
# Out:
# <ipython-input-25-d206bb50616a>:8: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = cleand_df.corr()

# %% [markdown]
# #### `age`-- 'Age' factor have a strong impact on charges. Older individuals tend to have higher charges compared to younger ones.
# #### `smoker`-- 'Smoker' factor have a strong impact on charges.The difference in charges between smokers and non-smokers is Smokers have significantly higher charges compared to non-smokers.
# #### `sex`-- There is no relationship beteen 'sex' and 'charges'. Charges doesn't vary between males and females and are similar for both.
# #### `bmi`-- Their is no relationship between 'bmi' and 'charges'.
# #### `regions`-- There are no significant regional(northeast, southeast, southwest, northwest)  variations The average charges or the distribution of charges across different regions is almost similar. Compare to others,southeast region consumes high range of charges.
# #### `children` -- cildren feature having no Impact on charges.
